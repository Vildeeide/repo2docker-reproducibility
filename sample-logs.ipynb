# %% [markdown]
# # Sample reading collected result data
#
# This notebook demonstrates reading build logs for failed builds
# from the "pipfile success" runs,
# which is one of the less expected results.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First, list the csv files for our runs:

# %%
ls data_collection
# Out:
# build_repo.csv                    repo2docker-checker_test1.csv
# from_event_archive.csv            results.csv
# import_error.csv                  success_default_requirements.csv
# install_failed.csv                success_pipfile.csv
# julia.csv                         success_with_dependencies.csv
# r.csv                             success_without_dependencies.csv

# %% [markdown]
# Load the results into a data frame:

# %%
df = pd.read_csv("data_collection/success_pipfile.csv", sep=";", index_col="No")
df.head()
# Out:
#                                          Repo  \
# No
# 1                          haishenming/uda-u5
# 2   driscollis/NebraskaCode_Python_Decorators
# 3                            kazup0n/lifegame
# 4                   onyxfish/nicar-2017-agate
# 5       datadesk/python-road-clipping-example
#
#             repo2docker-checker results
# No
# 1                                  1 ok
# 2                  1 failure, TypeError
# 3                                  1 ok
# 4                          Build failed
# 5   1 failure. Cell execution timed out

# %% [markdown]
# Result data is stored in csv files based on the repo URL and timestamp of the run:

# %%
cat runs/github.com/a/agconti/dog-walks/results/results-master-2020-07-23T11.46.csv
# Out:
# repo,ref,resolved_ref,last_modified,kind,test_id,success,path,timestamp,run_id,repo2docker_version
# https://github.com/agconti/dog-walks,master,8b6c692,2018-03-22T22:50:42-04:00,build,build,False,github.com/a/agconti/dog-walks/logs/build-master-2020-07-23T11.46.txt,2020-07-23T11:46:58.837968,2020-07-23T11.46,0.11.0

# %%
from textwrap import indent

def tail(path, max_lines=100, max_line_length=100, skip=0):
    """Ineficient tail with line truncation"""
    with open(path) as f:
        log_lines = f.readlines()[-(max_lines+skip):-skip or None]
    for line in log_lines:
        if len(line) > max_line_length:
            print(indent(line[:max_line_length-3] + "...", "  "))
            print(indent(line[-(max_line_length-3):], "  ..."))
        else:
            print(indent(line.rstrip(), "  "))

# %%
def results_for_repo(repo_slug):
    """Collect results for a given repo"""
    repo_slug = repo_slug.lower()
    repo_url = f"https://github.com/{repo_slug}"
    c = repo_slug.lower()[0]
    results_dir = os.path.join("runs", "github.com", repo_slug[0], repo_slug, "results")
    
    # collect data from csv files for runs
    csvs = sorted(glob.glob(os.path.join(results_dir, "*.csv")))
    frames = []
    for csv in csvs:
        frame = pd.read_csv(csv)
        if len(frame):
            frames.append(pd.read_csv(csv, parse_dates=True))
    if not frames:
        return
    return pd.concat(frames).reset_index(drop=True).sort_values("timestamp")

# %%
results_for_repo(df.Repo[9])
# Out:
#                                      repo     ref resolved_ref  \
# 0  https://github.com/samzhuwj/use-pyfpdf  master      049ad9b
# 1  https://github.com/samzhuwj/use-pyfpdf  master      049ad9b
#
#                last_modified      kind           test_id  success  \
# 0  2018-01-20T00:11:26+08:00     build             build     True
# 1  2018-01-20T00:11:26+08:00  notebook  use-pyfpdf.ipynb    False
#
#                                                 path  \
# 0  github.com/s/samzhuwj/use-pyfpdf/logs/build-ma...
# 1  github.com/s/samzhuwj/use-pyfpdf/logs/test-not...
#
#                     timestamp            run_id repo2docker_version
# 0  2020-07-23T11:55:56.416858  2020-07-23T11.55              0.11.0
# 1  2020-07-23T11:55:56.416858  2020-07-23T11.55              0.11.0

# %%
import glob
import os

for repo_slug in df.Repo:
    result_data = results_for_repo(repo_slug)
    if result_data is None:
        continue
    build_failures = result_data[(result_data.kind=="build") & (~result_data.success)]
    if len(build_failures):
        
        log_file = os.path.join("runs", build_failures.path.tail(1).item())
        print(f"\n\n\n{repo_slug} build log failure: {log_file}")
        tail(log_file, 20, max_line_length=128, skip=8)
# Out:
# onyxfish/nicar-2017-agate build log failure: runs/github.com/o/onyxfish/nicar-2017-agate/logs/build-master-2020-07-23T11.35.txt
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 795, in do_install_dependencies
#       lockfile = project.get_or_create_lockfile(from_pipfile=True)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/project.py", line 756, in get_or_create_lockfile
#       path=self.lockfile_location, data=lockfile_dict, meta_from_project=False
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/lockfile.py", line 209, in ...
#   ...rv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/lockfile.py", line 209, in from_data
#
#       lockfile = plette.lockfiles.Lockfile(data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 37, in __init__
#       self.validate(data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/lockfiles.py", line 80, in validate
#       klass.validate(data[key])
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/sections.py", line 70, in validate
#       klass.validate(data[key])
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 132, in validate
#       cls.item_class.validate(d)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 67, in validate
#       return validate(cls, data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/pipfile.py", line 59, in va...
#   ..."/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/pipfile.py", line 59, in validate
#
#       raise plette.models.base.ValidationError(data, v)
#   plette.models.base.ValidationError: {'url': 'https://pypi.python.org/simple', 'verify_ssl': True}
#   Removing intermediate container af074c7ac6f2
#
#
#
# alexbseaton/complex-mappings build log failure: runs/github.com/a/alexbseaton/complex-mappings/logs/build-master-2020-07-23T11.57.txt
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring colorama: markers 'sys_platform == "win32"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing numpy==1.14.0 --hash=sha256:428cd3c0b197cf857671353d8c85833193921af9fafcc169a1f29c718...
#   ...c765051a1baf4d5070f63d05010f --hash=sha256:3de643935b212307b420248018323a44ec51987a336d1d747c1322afc3c099fb! Will try again.
#
#   An error occurred while installing pyzmq==16.0.3 --hash=sha256:f88d8ffa32bf729bed806ca3205846ed98b61f149562dc828db5c...
#   ...23667c3c847683bc3ae1929093f5 --hash=sha256:8a883824147523c0fe76d247dd58994c1c28ef07f1cc5dde595a4fd1c28f2580! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 862, in ...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 862, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, False, failed_deps_queue, retry=False)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in ...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting numpy==1.14.0', '  Using...
#   ..., '    Running setup.py install for numpy: started', "    Running setup.py install for numpy: finished with status 'error'"]
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...aged --compile --install-headers /srv/conda/envs/notebook/include/python3.7m/numpy Check the logs for full command output.']
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 4d1361f1be4e
#
#
#
# agconti/dog-walks build log failure: runs/github.com/a/agconti/dog-walks/logs/build-master-2020-07-23T11.46.txt
#   Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing terminado==0.8.1 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a5...
#   ...6059947a593322e8a553cc4c067a --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b743fe7cad8b927! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.8....
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 245131d650f2
#
#
#
# VioletVivirand/lime-mechine-learning-demo build log failure: runs/github.com/v/violetvivirand/lime-mechine-learning-demo/logs/build-master-2020-07-23T11.51.txt
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing terminado==0.6 ; sys_platform != 'win32' --hash=sha256:2c0ba1f624067dccaaead7d2247cfe...
#   ....6 ; sys_platform != 'win32' --hash=sha256:2c0ba1f624067dccaaead7d2247cfe029806355cef124dc2ccb53c83229f0126! Will try again.
#
#   An error occurred while installing xgboost==0.6a2 --hash=sha256:ebc4e2bf8c8266212e342ff8ec4f6ae469e8c41a05d099b6778d...
#   ...le installing xgboost==0.6a2 --hash=sha256:ebc4e2bf8c8266212e342ff8ec4f6ae469e8c41a05d099b6778de8424ce32563! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 862, in ...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 862, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, False, failed_deps_queue, retry=False)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in ...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.6'...
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container ea792ec765df
#
#
#
# TrentoCrowdAI/datasets-preprocessor build log failure: runs/github.com/t/trentocrowdai/datasets-preprocessor/logs/build-master-2020-07-23T12.06.txt
#   Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing terminado==0.8.1 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a5...
#   ...6059947a593322e8a553cc4c067a --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b743fe7cad8b927! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.8....
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container f7855d66bcdf
#
#
#
# trevordmiller/practice-jupyterlab build log failure: runs/github.com/t/trevordmiller/practice-jupyterlab/logs/build-master-2020-07-27T06.48.txt
#         numpy/random/mtrand/mtrand.c:44866:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you...
#   ...and/mtrand.c:44866:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_value’; did you mean ‘curexc_value’?
#
#              tstate->exc_value = local_value;
#                      ^~~~~~~~~
#                      curexc_value
#         numpy/random/mtrand/mtrand.c:44867:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did...
#   ...nd.c:44867:13: error: ‘PyThreadState {aka struct _ts}’ has no member named ‘exc_traceback’; did you mean ‘curexc_traceback’?
#
#              tstate->exc_traceback = local_tb;
#                      ^~~~~~~~~~~~~
#                      curexc_traceback
#         error: Command "gcc -pthread -B /srv/conda/envs/notebook/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fw...
#   .../numpy/random/mtrand/mtrand.o -MMD -MF build/temp.linux-x86_64-3.7/numpy/random/mtrand/mtrand.o.d" failed with exit status 1
#
#         ----------------------------------------
#     ERROR: Command errored out with exit status 1: /srv/conda/envs/notebook/bin/python -u -c 'import sys, setuptools, tokenize;...
#   ...mpile --install-headers /tmp/pip-build-env-29rb4wke/overlay/include/python3.7m/numpy Check the logs for full command output.
#
#     ----------------------------------------
#   ERROR: Command errored out with exit status 1: /srv/conda/envs/notebook/bin/python /srv/conda/envs/notebook/lib/python3.7/sit...
#   ....12.1; python_version=='"'"'3.6'"'"'' 'numpy==1.13.1; python_version>='"'"'3.7'"'"'' Check the logs for full command output.
#
#   An error occurred while installing pandas==0.22.0 --hash=sha256:68ac484e857dcbbd07ea7c6f516cc67f7f143f5313d9bc661470e7f4...
#   ...6604f990bc98e1b71ebf07e45b44 --hash=sha256:44a94091dd71f05922eec661638ec1a35f26d573c119aa2fad964f10a2880e6c! Will try again.
#
#   An error occurred while installing terminado==0.8.1 --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b...
#   ...43cfbaeb16831b743fe7cad8b927 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a553cc4c067a! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#
#
#
# sciyoshi/riddler build log failure: runs/github.com/s/sciyoshi/riddler/logs/build-master-2020-07-23T12.47.txt
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in do_init
#       pypi_mirror=pypi_mirror,
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 797, in do_install_dependencies
#       lockfile = project.get_or_create_lockfile()
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/project.py", line 778, in get_or_create_lockfile
#       path=self.lockfile_location, data=lockfile_dict, meta_from_project=False
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/lockfile.py", line 209, in ...
#   ...rv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/lockfile.py", line 209, in from_data
#
#       lockfile = plette.lockfiles.Lockfile(data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 37, in __ini...
#   ...  File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 37, in __init__
#
#       self.validate(data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/lockfiles.py", line 80, in validate
#       klass.validate(data[key])
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/sections.py", line 68, in v...
#   ...m  File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/sections.py", line 68, in validate
#
#       super(Meta, cls).validate(data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 67, in valid...
#   ...  File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/plette/models/base.py", line 67, in validate
#
#       return validate(cls, data)
#     File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/pipfile.py", line ...
#   ..."/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/vendor/requirementslib/models/pipfile.py", line 59, in validate
#
#       raise plette.models.base.ValidationError(data, v)
#   plette.models.base.ValidationError: {'sources': [{'url': 'https://pypi.python.or...
#   ...hon.org'}], 'requires': {}, 'hash': {'sha256': 'e178de44624f2fd013ad526ef3bb19ffa00700b251bfb138758eb558c88c307b'}}
#
#   Removing intermediate container 175ac54c1f5c
#
#
#
# jean-k-cp/python101 build log failure: runs/github.com/j/jean-k-cp/python101/logs/build-master-2020-07-23T12.54.txt
#   Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing terminado==0.8.1 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a5...
#   ...6059947a593322e8a553cc4c067a --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b743fe7cad8b927! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 859, in ...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 763, in ...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in ...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.8.1', '  Us...
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container c6d5c577b5e4
#
#
#
# izikeros/blog build log failure: runs/github.com/i/izikeros/blog/logs/build-master-2020-07-23T13.05.txt
#    ---> a6acb759ec80
#   Step 47/54 : RUN (cd . &&                     PATH="${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install...
#   ..."${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install --ignore-pipfile --system --dev                 )
#
#    ---> Running in 9e1014a39322
#   Installing dependencies from Pipfile.lock (6bf2ca)…
#   An error occurred while installing terminado==0.8.2 --hash=sha256:d9d012de63acb8223ac969c17c3043337c2fcfd28f3aea1ee429b3...
#   ...cfd28f3aea1ee429b345d01ef460 --hash=sha256:de08e141f83c3a0798b050ecb097ab6259c3f0331b2f7b7750c9075ced2c20c2! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 859, in ...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.8....
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 9e1014a39322
#
#
#
# farnoy/ml build log failure: runs/github.com/f/farnoy/ml/logs/build-master-2020-07-27T06.48.txt
#   Step 44/54 : COPY src/ ${REPO_DIR}
#    ---> 1686bc1f8581
#   Step 45/54 : RUN chown -R ${NB_USER}:${NB_USER} ${REPO_DIR}
#    ---> Running in 3dd4e1dd7cf3
#   Removing intermediate container 3dd4e1dd7cf3
#    ---> 801d4d0ba95e
#   Step 46/54 : USER ${NB_USER}
#    ---> Running in f678925a7245
#   Removing intermediate container f678925a7245
#    ---> 31aa69507cbe
#   Step 47/54 : RUN (cd . &&                     PATH="${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install...
#   ..."${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install --ignore-pipfile --system --dev                 )
#
#    ---> Running in 801e806f2529
#   Installing dependencies from Pipfile.lock (586379)…
#   An error occurred while installing numpy==1.14.1 --hash=sha256:e2335d56d2fd9fc4e3a3f2d3148aafec4962682375f429f05c45a64da...
#   ...5ff90bd4180ec99f0f0c73050b5e --hash=sha256:fa0944650d5d3fb95869eaacd8eedbd2d83610c85e271bd9d3495ffa9bc4dc9c! Will try again.
#
#   An error occurred while installing terminado==0.8.1 --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b...
#   ...43cfbaeb16831b743fe7cad8b927 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a553cc4c067a! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#
#
#
# elisabeth-berg/trending-food build log failure: runs/github.com/e/elisabeth-berg/trending-food/logs/build-master-2020-07-23T13.12.txt
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/usr/local/bin/jupyter-repo2docker", line 8, in <module>
#       sys.exit(main())
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/__main__.py", line 348, in main
#       r2d.start()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 743, in start
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#
#
#
# budiryan/colorspace-analysis build log failure: runs/github.com/b/budiryan/colorspace-analysis/logs/build-master-2020-07-27T06.44.txt
#     ----------------------------------------
#   ERROR: Command errored out with exit status 1: /srv/conda/envs/notebook/bin/python /srv/conda/envs/notebook/lib/python3.7/sit...
#   ....12.1; python_version=='"'"'3.6'"'"'' 'numpy==1.13.1; python_version>='"'"'3.7'"'"'' Check the logs for full command output.
#
#   An error occurred while installing pandas==0.22.0 --hash=sha256:68ac484e857dcbbd07ea7c6f516cc67f7f143f5313d9bc661470e7f4...
#   ...6604f990bc98e1b71ebf07e45b44 --hash=sha256:44a94091dd71f05922eec661638ec1a35f26d573c119aa2fad964f10a2880e6c! Will try again.
#
#   An error occurred while installing pyyaml==3.12 --hash=sha256:3262c96a1ca437e7e4763e2843746588a965426550f3797a79fca9...
#   ...db5233c413dd824483989c000608 --hash=sha256:5ac82e411044fb129bae5cfbeb3ba626acb2af31a8d17d175004b70862a741a7! Will try again.
#
#   An error occurred while installing terminado==0.8.1 --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b...
#   ...43cfbaeb16831b743fe7cad8b927 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a553cc4c067a! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 862, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, False, failed_deps_queue, retry=False)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting numpy==1.14.2',...
#   ..., '    Running setup.py install for numpy: started', "    Running setup.py install for numpy: finished with status 'error'"]
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...aged --compile --install-headers /srv/conda/envs/notebook/include/python3.7m/numpy Check the logs for full command output.']
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 5788ed1e7422
#
#
#
# cjwinchester/ire-2018-python-for-data-analysis build log failure: runs/github.com/c/cjwinchester/ire-2018-python-for-data-analysis/logs/build-master-2020-07-23T13.25.txt
#
#
#
# elanorigby/pyquest build log failure: runs/github.com/e/elanorigby/pyquest/logs/build-master-2020-07-24T05.30.txt
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing pyzmq==16.0.3 --hash=sha256:f88d8ffa32bf729bed806ca3205846ed98b61f149562dc828db5c3a21...
#   ...23667c3c847683bc3ae1929093f5 --hash=sha256:8a883824147523c0fe76d247dd58994c1c28ef07f1cc5dde595a4fd1c28f2580! Will try again.
#
#   An error occurred while installing terminado==0.7 ; sys_platform != 'win32' --hash=sha256:57858bd06c6f20f66971aa6237...
#   ...f6d6ec70ded7d1d2fcbdad570c8a --hash=sha256:8c73bb515ca2dca9d5958877cfe0b418a2c59b0b7eef4a79a0c3e990eab1a318! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", l...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/cli/command.py", line 254, in install
#
#   [pipenv.exceptions.InstallError]:       editable_packages=state.installstate.editables,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 862, in ...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 862, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, False, failed_deps_queue, retry=False)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in ...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.7/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting pyzmq==16.0.3', '  Using...
#   ...v/conda/envs/notebook/lib/python3.7/site-packages/zmq/', '   from /srv/conda/envs/notebook/lib/python3.7/site-packages/~mq']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...aged --compile --install-headers /srv/conda/envs/notebook/include/python3.7m/pyzmq Check the logs for full command output.']
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 69fde50cfc8d
#
#
#
# paulolemus/machine-learning build log failure: runs/github.com/p/paulolemus/machine-learning/logs/build-master-2020-07-24T07.44.txt
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#       return self.request('GET', url, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 533, in request
#       resp = self.send(prep, **send_kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 646, in send
#       r = adapter.send(request, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/adapters.py", line 529, in send
#       raise ReadTimeout(e, request=request)
#   requests.exceptions.ReadTimeout: UnixHTTPConnectionPool(host='localhost', port=None): Read timed out. (read timeout=60)
#
#
#
# atonderski/tda231-ml-course build log failure: runs/github.com/a/atonderski/tda231-ml-course/logs/build-master-2020-07-24T05.31.txt
#   Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
#   To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
#   Ignoring appnope: markers 'sys_platform == "darwin"' don't match your environment
#   Looking in indexes: https://pypi.python.org/simple
#   An error occurred while installing terminado==0.8.1 --hash=sha256:55abf9ade563b8f9be1f34e4233c7b7bde726059947a593322e8a5...
#   ...6059947a593322e8a553cc4c067a --hash=sha256:65011551baff97f5414c67018e908110693143cfbaeb16831b743fe7cad8b927! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.6/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting terminado==0.8....
#   ...ing collected packages: terminado', '  Attempting uninstall: terminado', '    Found existing installation: terminado 0.8.3']
#
#   [pipenv.exceptions.InstallError]: ['WARNING: pip is being invoked by an old script wrapper. This will fail in a futu...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 51644c0664b8
#
#
#
# villeristi/applied-machine-learning-in-python build log failure: runs/github.com/v/villeristi/applied-machine-learning-in-python/logs/build-master-2020-07-24T05.34.txt
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#       return self.request('GET', url, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 533, in request
#       resp = self.send(prep, **send_kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 646, in send
#       r = adapter.send(request, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/adapters.py", line 529, in send
#       raise ReadTimeout(e, request=request)
#   requests.exceptions.ReadTimeout: UnixHTTPConnectionPool(host='localhost', port=None): Read timed out. (read timeout=60)
#
#
#
# foriequal0/grad-proj-tf-tutorial build log failure: runs/github.com/f/foriequal0/grad-proj-tf-tutorial/logs/build-master-2020-07-23T13.40.txt
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#       return self.request('GET', url, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 533, in request
#       resp = self.send(prep, **send_kwargs)
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 646, in send
#       r = adapter.send(request, **kwargs)
#     File "/usr/lib/python3/dist-packages/requests/adapters.py", line 529, in send
#       raise ReadTimeout(e, request=request)
#   requests.exceptions.ReadTimeout: UnixHTTPConnectionPool(host='localhost', port=None): Read timed out. (read timeout=60)
#
#
#
# onnudilol/ml_in_py build log failure: runs/github.com/o/onnudilol/ml_in_py/logs/build-master-2020-07-23T13.37.txt
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/usr/local/bin/jupyter-repo2docker", line 8, in <module>
#       sys.exit(main())
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/__main__.py", line 348, in main
#       r2d.start()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 743, in start
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#
#
#
# dgkim5360/the-elements-of-statistical-learning-notebooks build log failure: runs/github.com/d/dgkim5360/the-elements-of-statistical-learning-notebooks/logs/build-master-2020-07-23T13.31.txt
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/usr/local/bin/jupyter-repo2docker", line 8, in <module>
#       sys.exit(main())
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/__main__.py", line 348, in main
#       r2d.start()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 743, in start
#       self.build()
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 658, in build
#       if self.find_image():
#     File "/usr/local/lib/python3.8/dist-packages/repo2docker/app.py", line 620, in find_image
#       for image in client.images():
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/image.py", line 90, in images
#       res = self._result(self._get(self._url("/images/json"), params=params),
#     File "/usr/local/lib/python3.8/dist-packages/docker/utils/decorators.py", line 46, in inner
#       return f(self, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/docker/api/client.py", line 230, in _get
#       return self.get(url, **self._set_request_timeout(kwargs))
#     File "/usr/lib/python3/dist-packages/requests/sessions.py", line 546, in get
#
#
#
# GustavoDinizMonteiro/inverted_index build log failure: runs/github.com/g/gustavodinizmonteiro/inverted_index/logs/build-master-2020-07-23T13.19.txt
#    ---> 6411aee29b9c
#   Step 47/54 : RUN (cd . &&                     PATH="${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install...
#   ..."${KERNEL_PYTHON_PREFIX}/bin:$PATH"                         pipenv install --ignore-pipfile --system --dev                 )
#
#    ---> Running in 59e62ccf53e4
#   Installing dependencies from Pipfile.lock (686e1f)…
#   An error occurred while installing ptyprocess==0.5.2 --hash=sha256:e64193f0047ad603b71f202332ab5527c5e52aa7c8b609704fc28...
#   ...2aa7c8b609704fc28c0dc20c4365 --hash=sha256:e8c43b5eee76b2083a9badde89fd1bbce6c8942d1045146e100b7b5e014f4f1a! Will try again.
#
#   Installing initially failed dependencies…
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 187...
#   ...ptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 1874, in do_install
#
#   [pipenv.exceptions.InstallError]:       keep_outdated=keep_outdated
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line...
#   ...xceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 1253, in do_init
#
#   [pipenv.exceptions.InstallError]:       pypi_mirror=pypi_mirror,
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line...
#   ...llError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 859, in do_install_dependencies
#
#   [pipenv.exceptions.InstallError]:       retry_list, procs, failed_deps_queue, requirements_dir, **install_kwargs
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line...
#   ...ions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 763, in batch_install
#
#   [pipenv.exceptions.InstallError]:       _cleanup_procs(procs, not blocking, failed_deps_queue, retry=retry)
#   [pipenv.exceptions.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line...
#   ...ons.InstallError]:   File "/srv/conda/envs/notebook/lib/python3.5/site-packages/pipenv/core.py", line 681, in _cleanup_procs
#
#   [pipenv.exceptions.InstallError]:       raise exceptions.InstallError(c.dep.name, extra=err_lines)
#   [pipenv.exceptions.InstallError]: ['Looking in indexes: https://pypi.python.org/simple', 'Collecting ptyprocess==0.5...
#   ...0.5.2-py2.py3-none-any.whl', 'Installing collected packages: ptyprocess', '  Found existing installation: ptyprocess 0.6.0']
#
#   [pipenv.exceptions.InstallError]: ["Cannot uninstall 'ptyprocess'. It is a distutils installed project and thus we c...
#   ...led project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall."]
#
#   ERROR: ERROR: Package installation failed...
#   Removing intermediate container 59e62ccf53e4

# %% [markdown]
# In many cases, Pipfile and/or Pipfile.lock are pinning packages such as numpy
# to versions that do not work with current Python 3.8, but Python itself is not pinned,
# despite *suport* for specifying Python version in Pipfiles.
